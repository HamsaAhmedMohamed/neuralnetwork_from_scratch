# %% [markdown]
# The purpose is to gain valuable understanding of the math behind Feed-forward neutral networks.
# Instead of using already known libraries.
# \subsection*{The math}
# let input be $x_1,x_2,..,x_d$. Let ouput neuron be $i$ detoned $z_i(\mathbf{x})$.
